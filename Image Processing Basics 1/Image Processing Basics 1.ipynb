# %% [markdown]
# PIL
#
# PIL is an important Image processing library in Python.
#
# Install :
#
# pip install pillow
#
# Matplotlib

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# reading png image 
img = img.imread('image1.jpg')

plt.imshow(img)

# %%
# modifying the shape of the image
lum1 = img[:, :, 0] 
plt.imshow(lum1)

# %%
plt.imshow(lum1, cmap ='hot') 
plt.colorbar()

# %%
imgplot = plt.imshow(lum1)
imgplot.set_cmap('nipy_spectral')

# %%
#data type of lum1

print(type(lum1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(lum1)
# Out:
# [[ 92  91  89 ... 169 168 169]
#  [110 110 110 ... 168 166 167]
#  [100 103 108 ... 164 163 164]
#  ...
#  [ 97  96  95 ... 144 147 147]
#  [ 99  99  98 ... 145 139 138]
#  [102 102 103 ... 149 137 137]]

# %%
len(lum1)
# Out:
# 320

# %%
len(lum1[300])
# Out:
# 658

# %% [markdown]
# So it is equal to the number of pixels in the Image. 320*658.

# %%
from PIL import Image

# %%
img2 = Image.open('people.jpg')


plt.imshow(img2)

# %%
img2.thumbnail((50, 50), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img2)

# %%
imgplot1 = plt.imshow(img2, interpolation="nearest")

# %%
imgplot2 = plt.imshow(img2, interpolation="bicubic")

# %%
#some more interesting stuff

file='image1.jpg'

with Image.open(file) as image: 
    width, height = image.size 
#Image width, height is be obtained

# %%
width
# Out:
# 658

# %%
height
# Out:
# 320

# %%
#this was the dimensions we found earlier

# %%
#Relative Path 
img3 = Image.open("image1.jpg")  
          
#Angle given 
img_rot= img3.rotate(180)  
          
#Saved in the same relative location 
img_rot.save("rotated_picture.jpg")

# %%
img_rot
# Out:
# <PIL.Image.Image image mode=RGB size=658x320 at 0x1E6D626DEC8>

# %%
#transposing image  
transposed_img = img3.transpose(Image.FLIP_LEFT_RIGHT)

# %%
transposed_img
# Out:
# <PIL.Image.Image image mode=RGB size=658x320 at 0x1E6D62713C8>

# %%
#Saved in the same relative location 
transposed_img.save("transposed_img.jpg")

# %%
#thank you
